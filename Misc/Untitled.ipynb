# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import LSTM, Input
from tensorflow.keras.layers import Dense, Dropout

def model_LSTM(drop_rate, units, time_sequence):

    model = Sequential()

    model.add(LSTM(units, return_sequences = True, input_shape = (time_sequence, 1)))
    model.add(Dropout(drop_rate))

    model.add(LSTM(units, return_sequences = True))
    model.add(Dropout(drop_rate))

    model.add(LSTM(units, return_sequences = True))
    model.add(Dropout(drop_rate))

    model.add(LSTM(units))
    model.add(Dropout(drop_rate))

    model.add(Dense(1))
    
    return model
 #   input_data = Input(batch_shape=(batch_size,input_size,input_dimension))
  #  l1 = LSTM(units, return_sequences = True)(input_data)
   # b1 = Dropout(0.2)(l1)
    #l2 = LSTM(units, return_sequences=True)(b1)
   # b2 = Dropout(0.2)(l2)
   # l3 = LSTM(units, return_sequences=True)(b2)
   # b3 = Dropout(0.2)(l3)
   # l4 = LSTM(units, return_sequences=True)(b3)
   # b4 = Dropout(0.2)(l4)
   # output = Dense(1)(b4)
    
   # model_lstm = Model(inputs=input_data,outputs=output)
   # model_lstm.summary()
   # return model_lstm

# %%
from tensorflow.keras.optimizers import Adam

#from tensorflow.keras import metrics
#from tensorflow.keras import losses
#initialize the model paramters
batch_size = 16
units = 40
drop_rate = 0.2
LR = 0.001
epochs = 100
input_dimension = 1
#load the training and test data
X_train, y_train, X_val, y_val = data_loader()

#generate the model and compile it
model = model_LSTM(drop_rate, units, X_train.shape[1])
model.compile(loss='mean_squared_error', optimizer=Adam(lr=LR), metrics=['mean_absolute_error'])

#train the model 
History = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data = (X_val, y_val), verbose=2)
#predict the prices
predicted_stock_price = model.predict(X_val)


import matplotlib.pyplot as plt

#def plotter():
   # fig = plt.plot(real_stock_price, color = 'black', label = 'TATA Stock Price')
    #Training vs Validation Learning loss 
fig = plt.figure(figsize=(4, 4))
plt.title("Learning curve")
plt.plot(History.history["loss"], label="loss")
plt.plot(History.history["val_loss"], label="val_loss")
plt.plot(np.argmin(History.history["val_loss"]),
         np.min(History.history["val_loss"]),
         marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Loss Value")
plt.legend(); 

#Train and test accuracy plot
fig2 = plt.figure(figsize=(4,4))
plt.title("Mean Absolute Erro Curve")
plt.plot(History.history["mean_absolute_error"], label="mean_absolute_error")
plt.plot(History.history["val_mean_absolute_error"], label="val_mean_absolute_error")
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend(); 

fig3 = plt.figure(figsize=(4,4))
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted TATA Stock Price')
plt.title('TATA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TATA Stock Price')
plt.legend()
plt.show()

#predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# Train on 1920 samples, validate on 16 samples
# Epoch 1/100
# 1920/1920 - 14s - loss: 0.0082 - mean_absolute_error: 0.0579 - val_loss: 0.0014 - val_mean_absolute_error: 0.0313
# Epoch 2/100
# 1920/1920 - 11s - loss: 0.0035 - mean_absolute_error: 0.0423 - val_loss: 0.0014 - val_mean_absolute_error: 0.0320
# Epoch 3/100
# 1920/1920 - 11s - loss: 0.0036 - mean_absolute_error: 0.0429 - val_loss: 0.0029 - val_mean_absolute_error: 0.0448
# Epoch 4/100
# 1920/1920 - 9s - loss: 0.0029 - mean_absolute_error: 0.0377 - val_loss: 0.0024 - val_mean_absolute_error: 0.0426
# Epoch 5/100
# 1920/1920 - 10s - loss: 0.0027 - mean_absolute_error: 0.0366 - val_loss: 0.0020 - val_mean_absolute_error: 0.0365
# Epoch 6/100
# 1920/1920 - 10s - loss: 0.0022 - mean_absolute_error: 0.0334 - val_loss: 0.0021 - val_mean_absolute_error: 0.0407
# Epoch 7/100
# 1920/1920 - 9s - loss: 0.0023 - mean_absolute_error: 0.0333 - val_loss: 0.0033 - val_mean_absolute_error: 0.0453
# Epoch 8/100
# 1920/1920 - 10s - loss: 0.0023 - mean_absolute_error: 0.0334 - val_loss: 0.0031 - val_mean_absolute_error: 0.0447
# Epoch 9/100
# 1920/1920 - 9s - loss: 0.0021 - mean_absolute_error: 0.0321 - val_loss: 0.0027 - val_mean_absolute_error: 0.0428
# Epoch 10/100
# 1920/1920 - 9s - loss: 0.0020 - mean_absolute_error: 0.0318 - val_loss: 0.0030 - val_mean_absolute_error: 0.0473
# Epoch 11/100
# 1920/1920 - 10s - loss: 0.0020 - mean_absolute_error: 0.0313 - val_loss: 0.0026 - val_mean_absolute_error: 0.0433
# Epoch 12/100
# 1920/1920 - 10s - loss: 0.0019 - mean_absolute_error: 0.0302 - val_loss: 0.0029 - val_mean_absolute_error: 0.0457
# Epoch 13/100
# 1920/1920 - 10s - loss: 0.0018 - mean_absolute_error: 0.0295 - val_loss: 0.0029 - val_mean_absolute_error: 0.0458
# Epoch 14/100
# 1920/1920 - 10s - loss: 0.0017 - mean_absolute_error: 0.0295 - val_loss: 0.0059 - val_mean_absolute_error: 0.0639
# Epoch 15/100
# 1920/1920 - 10s - loss: 0.0018 - mean_absolute_error: 0.0291 - val_loss: 0.0037 - val_mean_absolute_error: 0.0535
# Epoch 16/100
# 1920/1920 - 10s - loss: 0.0015 - mean_absolute_error: 0.0268 - val_loss: 0.0042 - val_mean_absolute_error: 0.0557
# Epoch 17/100
# 1920/1920 - 10s - loss: 0.0018 - mean_absolute_error: 0.0294 - val_loss: 0.0028 - val_mean_absolute_error: 0.0458
# Epoch 18/100
# 1920/1920 - 10s - loss: 0.0015 - mean_absolute_error: 0.0267 - val_loss: 0.0038 - val_mean_absolute_error: 0.0541
# Epoch 19/100
# 1920/1920 - 10s - loss: 0.0015 - mean_absolute_error: 0.0267 - val_loss: 0.0030 - val_mean_absolute_error: 0.0417
# Epoch 20/100
# 1920/1920 - 10s - loss: 0.0017 - mean_absolute_error: 0.0278 - val_loss: 0.0024 - val_mean_absolute_error: 0.0420
# Epoch 21/100
# 1920/1920 - 10s - loss: 0.0014 - mean_absolute_error: 0.0262 - val_loss: 0.0024 - val_mean_absolute_error: 0.0418
# Epoch 22/100
# 1920/1920 - 10s - loss: 0.0015 - mean_absolute_error: 0.0254 - val_loss: 0.0023 - val_mean_absolute_error: 0.0399
# Epoch 23/100
# 1920/1920 - 10s - loss: 0.0013 - mean_absolute_error: 0.0254 - val_loss: 0.0032 - val_mean_absolute_error: 0.0505
# Epoch 24/100
# 1920/1920 - 10s - loss: 0.0013 - mean_absolute_error: 0.0246 - val_loss: 0.0021 - val_mean_absolute_error: 0.0398
# Epoch 25/100
# 1920/1920 - 10s - loss: 0.0011 - mean_absolute_error: 0.0233 - val_loss: 0.0028 - val_mean_absolute_error: 0.0472
# Epoch 26/100
# 1920/1920 - 10s - loss: 0.0012 - mean_absolute_error: 0.0232 - val_loss: 0.0028 - val_mean_absolute_error: 0.0475
# Epoch 27/100
# 1920/1920 - 10s - loss: 0.0010 - mean_absolute_error: 0.0224 - val_loss: 0.0046 - val_mean_absolute_error: 0.0599
# Epoch 28/100
# 1920/1920 - 10s - loss: 0.0013 - mean_absolute_error: 0.0246 - val_loss: 0.0018 - val_mean_absolute_error: 0.0345
# Epoch 29/100
# 1920/1920 - 10s - loss: 0.0011 - mean_absolute_error: 0.0225 - val_loss: 0.0029 - val_mean_absolute_error: 0.0484
# Epoch 30/100
# 1920/1920 - 10s - loss: 0.0012 - mean_absolute_error: 0.0230 - val_loss: 0.0018 - val_mean_absolute_error: 0.0350
# Epoch 31/100
# 1920/1920 - 10s - loss: 0.0010 - mean_absolute_error: 0.0215 - val_loss: 0.0018 - val_mean_absolute_error: 0.0338
# Epoch 32/100
# 1920/1920 - 9s - loss: 9.4974e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0018 - val_mean_absolute_error: 0.0335
# Epoch 33/100
# 1920/1920 - 10s - loss: 0.0011 - mean_absolute_error: 0.0223 - val_loss: 0.0022 - val_mean_absolute_error: 0.0366
# Epoch 34/100
# 1920/1920 - 10s - loss: 9.9358e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0014 - val_mean_absolute_error: 0.0302
# Epoch 35/100
# 1920/1920 - 10s - loss: 0.0012 - mean_absolute_error: 0.0230 - val_loss: 0.0016 - val_mean_absolute_error: 0.0344
# Epoch 36/100
# 1920/1920 - 10s - loss: 0.0010 - mean_absolute_error: 0.0218 - val_loss: 0.0016 - val_mean_absolute_error: 0.0353
# Epoch 37/100
# 1920/1920 - 10s - loss: 0.0010 - mean_absolute_error: 0.0222 - val_loss: 0.0020 - val_mean_absolute_error: 0.0391
# Epoch 38/100
# 1920/1920 - 10s - loss: 9.8433e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0013 - val_mean_absolute_error: 0.0294
# Epoch 39/100
# 1920/1920 - 10s - loss: 9.1079e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0012 - val_mean_absolute_error: 0.0286
# Epoch 40/100
# 1920/1920 - 10s - loss: 0.0010 - mean_absolute_error: 0.0216 - val_loss: 0.0022 - val_mean_absolute_error: 0.0405
# Epoch 41/100
# 1920/1920 - 9s - loss: 0.0011 - mean_absolute_error: 0.0222 - val_loss: 0.0024 - val_mean_absolute_error: 0.0421
# Epoch 42/100
# 1920/1920 - 10s - loss: 0.0010 - mean_absolute_error: 0.0215 - val_loss: 0.0012 - val_mean_absolute_error: 0.0289
# Epoch 43/100
# 1920/1920 - 10s - loss: 0.0011 - mean_absolute_error: 0.0223 - val_loss: 0.0032 - val_mean_absolute_error: 0.0484
# Epoch 44/100
# 1920/1920 - 10s - loss: 9.6215e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0039 - val_mean_absolute_error: 0.0530
# Epoch 45/100
# 1920/1920 - 10s - loss: 8.4804e-04 - mean_absolute_error: 0.0198 - val_loss: 9.8799e-04 - val_mean_absolute_error: 0.0262
# Epoch 46/100
# 1920/1920 - 10s - loss: 8.7911e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0013 - val_mean_absolute_error: 0.0303
# Epoch 47/100
# 1920/1920 - 10s - loss: 9.5418e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0010 - val_mean_absolute_error: 0.0266
# Epoch 48/100
# 1920/1920 - 10s - loss: 9.6499e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0029 - val_mean_absolute_error: 0.0457
# Epoch 49/100
# 1920/1920 - 10s - loss: 9.4866e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0019 - val_mean_absolute_error: 0.0367
# Epoch 50/100
# 1920/1920 - 10s - loss: 0.0013 - mean_absolute_error: 0.0231 - val_loss: 0.0019 - val_mean_absolute_error: 0.0375
# Epoch 51/100
# 1920/1920 - 10s - loss: 8.6782e-04 - mean_absolute_error: 0.0197 - val_loss: 7.9530e-04 - val_mean_absolute_error: 0.0229
# Epoch 52/100
# 1920/1920 - 10s - loss: 8.9186e-04 - mean_absolute_error: 0.0203 - val_loss: 7.9704e-04 - val_mean_absolute_error: 0.0231
# Epoch 53/100
# 1920/1920 - 10s - loss: 8.7865e-04 - mean_absolute_error: 0.0200 - val_loss: 0.0011 - val_mean_absolute_error: 0.0282
# Epoch 54/100
# 1920/1920 - 10s - loss: 9.3995e-04 - mean_absolute_error: 0.0209 - val_loss: 0.0013 - val_mean_absolute_error: 0.0307
# Epoch 55/100
# 1920/1920 - 10s - loss: 8.7948e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0026 - val_mean_absolute_error: 0.0430
# Epoch 56/100
# 1920/1920 - 10s - loss: 7.6889e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0016 - val_mean_absolute_error: 0.0344
# Epoch 57/100
# 1920/1920 - 10s - loss: 9.5242e-04 - mean_absolute_error: 0.0206 - val_loss: 0.0021 - val_mean_absolute_error: 0.0391
# Epoch 58/100
# 1920/1920 - 10s - loss: 7.3273e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0032 - val_mean_absolute_error: 0.0487
# Epoch 59/100
# 1920/1920 - 10s - loss: 9.5858e-04 - mean_absolute_error: 0.0211 - val_loss: 9.8372e-04 - val_mean_absolute_error: 0.0265
# Epoch 60/100
# 1920/1920 - 10s - loss: 8.1038e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0013 - val_mean_absolute_error: 0.0311
# 1920/1920 - 9s - loss: 7.7996e-04 - mean_absolute_error: 0.0190 - val_loss: 0.0011 - val_mean_absolute_error: 0.0289
# Epoch 74/100
# 1920/1920 - 10s - loss: 7.5683e-04 - mean_absolute_error: 0.0188 - val_loss: 9.8704e-04 - val_mean_absolute_error: 0.0253
# Epoch 75/100
# 1920/1920 - 10s - loss: 8.1940e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0023 - val_mean_absolute_error: 0.0411
# Epoch 76/100
# 1920/1920 - 9s - loss: 8.4286e-04 - mean_absolute_error: 0.0195 - val_loss: 8.2864e-04 - val_mean_absolute_error: 0.0238
# Epoch 77/100
# 1920/1920 - 9s - loss: 7.9871e-04 - mean_absolute_error: 0.0190 - val_loss: 0.0012 - val_mean_absolute_error: 0.0291
# Epoch 78/100
# 1920/1920 - 10s - loss: 9.5084e-04 - mean_absolute_error: 0.0207 - val_loss: 0.0019 - val_mean_absolute_error: 0.0373
# Epoch 79/100
# 1920/1920 - 10s - loss: 7.4721e-04 - mean_absolute_error: 0.0190 - val_loss: 7.3512e-04 - val_mean_absolute_error: 0.0227
# Epoch 80/100
# 1920/1920 - 10s - loss: 7.5215e-04 - mean_absolute_error: 0.0186 - val_loss: 8.8087e-04 - val_mean_absolute_error: 0.0252
# Epoch 81/100
# 1920/1920 - 10s - loss: 8.1564e-04 - mean_absolute_error: 0.0190 - val_loss: 0.0020 - val_mean_absolute_error: 0.0379
# Epoch 82/100
# 1920/1920 - 10s - loss: 8.0846e-04 - mean_absolute_error: 0.0192 - val_loss: 7.4969e-04 - val_mean_absolute_error: 0.0229
# Epoch 83/100
# 1920/1920 - 10s - loss: 7.8878e-04 - mean_absolute_error: 0.0189 - val_loss: 6.9356e-04 - val_mean_absolute_error: 0.0223
# Epoch 84/100
# 1920/1920 - 10s - loss: 8.3671e-04 - mean_absolute_error: 0.0196 - val_loss: 7.6584e-04 - val_mean_absolute_error: 0.0236
# Epoch 85/100
# 1920/1920 - 10s - loss: 8.2667e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0027 - val_mean_absolute_error: 0.0451
# Epoch 86/100
# 1920/1920 - 10s - loss: 8.5781e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0018 - val_mean_absolute_error: 0.0359
# Epoch 87/100
# 1920/1920 - 10s - loss: 7.5945e-04 - mean_absolute_error: 0.0190 - val_loss: 7.0019e-04 - val_mean_absolute_error: 0.0223
# Epoch 88/100
# 1920/1920 - 10s - loss: 7.2134e-04 - mean_absolute_error: 0.0181 - val_loss: 6.3027e-04 - val_mean_absolute_error: 0.0209
# Epoch 89/100
# 1920/1920 - 9s - loss: 8.2240e-04 - mean_absolute_error: 0.0198 - val_loss: 6.6569e-04 - val_mean_absolute_error: 0.0216
# Epoch 90/100
# 1920/1920 - 10s - loss: 7.5104e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0028 - val_mean_absolute_error: 0.0457
# Epoch 91/100
# 1920/1920 - 10s - loss: 7.0509e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0023 - val_mean_absolute_error: 0.0403
# Epoch 92/100
# 1920/1920 - 10s - loss: 8.2322e-04 - mean_absolute_error: 0.0198 - val_loss: 8.8376e-04 - val_mean_absolute_error: 0.0253
# Epoch 93/100
# 1920/1920 - 10s - loss: 6.5959e-04 - mean_absolute_error: 0.0178 - val_loss: 7.8573e-04 - val_mean_absolute_error: 0.0239
# Epoch 94/100
# 1920/1920 - 10s - loss: 8.5853e-04 - mean_absolute_error: 0.0192 - val_loss: 0.0035 - val_mean_absolute_error: 0.0517
# Epoch 95/100
# 1920/1920 - 10s - loss: 6.5242e-04 - mean_absolute_error: 0.0179 - val_loss: 8.5753e-04 - val_mean_absolute_error: 0.0249
# Epoch 96/100
# 1920/1920 - 10s - loss: 7.6419e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0011 - val_mean_absolute_error: 0.0279
# Epoch 97/100
# 1920/1920 - 10s - loss: 7.4943e-04 - mean_absolute_error: 0.0189 - val_loss: 6.2620e-04 - val_mean_absolute_error: 0.0208
# Epoch 98/100
# 1920/1920 - 10s - loss: 6.8364e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0015 - val_mean_absolute_error: 0.0330
# Epoch 99/100
# 1920/1920 - 10s - loss: 7.8447e-04 - mean_absolute_error: 0.0187 - val_loss: 7.4934e-04 - val_mean_absolute_error: 0.0233
# Epoch 100/100
# 1920/1920 - 10s - loss: 8.6492e-04 - mean_absolute_error: 0.0198 - val_loss: 0.0011 - val_mean_absolute_error: 0.0280
