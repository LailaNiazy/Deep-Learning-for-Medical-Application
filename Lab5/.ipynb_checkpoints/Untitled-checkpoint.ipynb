# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

def data_loader():
    # load csv files:
    dataset_train = pd.read_csv('/Lab1/Lab5/train_data_stock.csv')
    dataset_val = pd.read_csv('/Lab1/Lab5/val_data_stock.csv')

    # reverse data so that they go from oldest to newest:
    dataset_train = dataset_train.iloc[::-1]
    dataset_val = dataset_val.iloc[::-1]

    # concatenate training and test datasets:
    dataset_total = pd.concat((dataset_train['Open'], dataset_val['Open']), axis=0) 

    # select the values from the “Open” column as the variables to be predicted:
    training_set = dataset_train.iloc[:, 1:2].values
    val_set = dataset_val.iloc[:, 1:2].values

    #normalize the data from 0 to 1
    sc = MinMaxScaler(feature_range=(0, 1))
    training_set_scaled = sc.fit_transform(training_set)


    # split training data into T time steps:
    X_train = []
    y_train = []
    T = 60

    for i in range(T, len(training_set)):
        X_train.append(training_set_scaled[i-T:i, 0])
        y_train.append(training_set_scaled[i, 0])
    X_train, y_train = np.array(X_train), np.array(y_train)

    # normalize the validation set according to the normalization applied to the training set:
    inputs = dataset_total[len(dataset_total) - len(dataset_val) - 60:].values
    inputs = inputs.reshape(-1, 1)
    inputs = sc.transform(inputs)

    # split validation data into T time steps:
    X_val = []
    for i in range(T, T + len(val_set)):
        X_val.append(inputs[i-T:i, 0])
    X_val = np.array(X_val)
    y_val = sc.transform(val_set)

    # reshape to 3D array (format needed by LSTMs -> number of samples,timesteps, input dimension)
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    X_val = np.reshape(X_val, (X_val.shape[0], X_val.shape[1], 1))

    return X_train, y_train, X_val, y_val

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import LSTM, Input
from tensorflow.keras.layers import Dense, Dropout

def model_LSTM(drop_rate, units, time_sequence):

    model = Sequential()

    model.add(LSTM(units, return_sequences = True, input_shape = (time_sequence, 1)))
    model.add(Dropout(drop_rate))

    model.add(LSTM(units, return_sequences = True))
    model.add(Dropout(drop_rate))

    model.add(LSTM(units, return_sequences = True))
    model.add(Dropout(drop_rate))

    model.add(LSTM(units))
    model.add(Dropout(drop_rate))

    model.add(Dense(1))
    
    return model
 #   input_data = Input(batch_shape=(batch_size,input_size,input_dimension))
  #  l1 = LSTM(units, return_sequences = True)(input_data)
   # b1 = Dropout(0.2)(l1)
    #l2 = LSTM(units, return_sequences=True)(b1)
   # b2 = Dropout(0.2)(l2)
   # l3 = LSTM(units, return_sequences=True)(b2)
   # b3 = Dropout(0.2)(l3)
   # l4 = LSTM(units, return_sequences=True)(b3)
   # b4 = Dropout(0.2)(l4)
   # output = Dense(1)(b4)
    
   # model_lstm = Model(inputs=input_data,outputs=output)
   # model_lstm.summary()
   # return model_lstm

# %%
from tensorflow.keras.optimizers import Adam

#from tensorflow.keras import metrics
#from tensorflow.keras import losses
#initialize the model paramters
batch_size = 16
units = 40
drop_rate = 0.2
LR = 0.001
epochs = 100
input_dimension = 1
#load the training and test data
X_train, y_train, X_val, y_val = data_loader()

#generate the model and compile it
model = model_LSTM(drop_rate, units, X_train.shape[1])
model.compile(loss='mean_squared_error', optimizer=Adam(lr=LR), metrics=['mean_absolute_error'])

#train the model 
History = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data = (X_val, y_val), verbose=2)
#predict the prices
predicted_stock_price = model.predict(X_val)


import matplotlib.pyplot as plt

#def plotter():
   # fig = plt.plot(real_stock_price, color = 'black', label = 'TATA Stock Price')
    #Training vs Validation Learning loss 
fig = plt.figure(figsize=(4, 4))
plt.title("Learning curve")
plt.plot(History.history["loss"], label="loss")
plt.plot(History.history["val_loss"], label="val_loss")
plt.plot(np.argmin(History.history["val_loss"]),
         np.min(History.history["val_loss"]),
         marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Loss Value")
plt.legend(); 

#Train and test accuracy plot
fig2 = plt.figure(figsize=(4,4))
plt.title("Mean Absolute Erro Curve")
plt.plot(History.history["mean_absolute_error"], label="mean_absolute_error")
plt.plot(History.history["val_mean_absolute_error"], label="val_mean_absolute_error")
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend(); 

fig3 = plt.figure(figsize=(4,4))
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted TATA Stock Price')
plt.title('TATA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TATA Stock Price')
plt.legend()
plt.show()

#predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# Train on 1920 samples, validate on 16 samples
# Epoch 1/100
# 1920/1920 - 16s - loss: 0.0139 - mean_absolute_error: 0.0782 - val_loss: 0.0015 - val_mean_absolute_error: 0.0320
# Epoch 2/100
# 1920/1920 - 12s - loss: 0.0042 - mean_absolute_error: 0.0476 - val_loss: 0.0014 - val_mean_absolute_error: 0.0319
# Epoch 3/100
# 1920/1920 - 11s - loss: 0.0042 - mean_absolute_error: 0.0457 - val_loss: 0.0043 - val_mean_absolute_error: 0.0543
# Epoch 4/100
# 1920/1920 - 12s - loss: 0.0040 - mean_absolute_error: 0.0434 - val_loss: 0.0014 - val_mean_absolute_error: 0.0321
# Epoch 5/100
# 1920/1920 - 12s - loss: 0.0037 - mean_absolute_error: 0.0418 - val_loss: 0.0017 - val_mean_absolute_error: 0.0338
# Epoch 6/100
# 1920/1920 - 12s - loss: 0.0031 - mean_absolute_error: 0.0396 - val_loss: 0.0016 - val_mean_absolute_error: 0.0332
# Epoch 7/100
# 1920/1920 - 12s - loss: 0.0034 - mean_absolute_error: 0.0400 - val_loss: 0.0051 - val_mean_absolute_error: 0.0599
# Epoch 8/100
# 1920/1920 - 11s - loss: 0.0026 - mean_absolute_error: 0.0364 - val_loss: 0.0016 - val_mean_absolute_error: 0.0342
# Epoch 9/100
# 1920/1920 - 12s - loss: 0.0026 - mean_absolute_error: 0.0356 - val_loss: 0.0019 - val_mean_absolute_error: 0.0361
# Epoch 10/100
# 1920/1920 - 12s - loss: 0.0025 - mean_absolute_error: 0.0351 - val_loss: 0.0048 - val_mean_absolute_error: 0.0562
# Epoch 11/100
# 1920/1920 - 11s - loss: 0.0025 - mean_absolute_error: 0.0355 - val_loss: 0.0028 - val_mean_absolute_error: 0.0416
# Epoch 12/100
# 1920/1920 - 11s - loss: 0.0024 - mean_absolute_error: 0.0347 - val_loss: 0.0060 - val_mean_absolute_error: 0.0640
# Epoch 13/100
# 1920/1920 - 11s - loss: 0.0023 - mean_absolute_error: 0.0331 - val_loss: 0.0038 - val_mean_absolute_error: 0.0488
# Epoch 14/100
# 1920/1920 - 11s - loss: 0.0022 - mean_absolute_error: 0.0329 - val_loss: 0.0023 - val_mean_absolute_error: 0.0394
# Epoch 15/100
# 1920/1920 - 11s - loss: 0.0022 - mean_absolute_error: 0.0323 - val_loss: 0.0051 - val_mean_absolute_error: 0.0579
# Epoch 16/100
# 1920/1920 - 11s - loss: 0.0024 - mean_absolute_error: 0.0332 - val_loss: 0.0035 - val_mean_absolute_error: 0.0472
# Epoch 17/100
# 1920/1920 - 11s - loss: 0.0021 - mean_absolute_error: 0.0316 - val_loss: 0.0039 - val_mean_absolute_error: 0.0503
# Epoch 18/100
# 1920/1920 - 11s - loss: 0.0020 - mean_absolute_error: 0.0307 - val_loss: 0.0035 - val_mean_absolute_error: 0.0481
# Epoch 19/100
# 1920/1920 - 11s - loss: 0.0019 - mean_absolute_error: 0.0304 - val_loss: 0.0054 - val_mean_absolute_error: 0.0597
# Epoch 20/100
# 1920/1920 - 11s - loss: 0.0019 - mean_absolute_error: 0.0298 - val_loss: 0.0028 - val_mean_absolute_error: 0.0444
# Epoch 21/100
# 1920/1920 - 11s - loss: 0.0017 - mean_absolute_error: 0.0288 - val_loss: 0.0030 - val_mean_absolute_error: 0.0460
# Epoch 22/100
# 1920/1920 - 11s - loss: 0.0018 - mean_absolute_error: 0.0290 - val_loss: 0.0044 - val_mean_absolute_error: 0.0551
# Epoch 23/100
# 1920/1920 - 11s - loss: 0.0016 - mean_absolute_error: 0.0283 - val_loss: 0.0027 - val_mean_absolute_error: 0.0448
# Epoch 24/100
# 1920/1920 - 11s - loss: 0.0019 - mean_absolute_error: 0.0290 - val_loss: 0.0028 - val_mean_absolute_error: 0.0461
# Epoch 25/100
# 1920/1920 - 11s - loss: 0.0019 - mean_absolute_error: 0.0298 - val_loss: 0.0029 - val_mean_absolute_error: 0.0469
# Epoch 26/100
# 1920/1920 - 10s - loss: 0.0018 - mean_absolute_error: 0.0289 - val_loss: 0.0031 - val_mean_absolute_error: 0.0491
# Epoch 27/100
# 1920/1920 - 11s - loss: 0.0018 - mean_absolute_error: 0.0284 - val_loss: 0.0029 - val_mean_absolute_error: 0.0471
# Epoch 28/100
# 1920/1920 - 11s - loss: 0.0018 - mean_absolute_error: 0.0284 - val_loss: 0.0046 - val_mean_absolute_error: 0.0575
# Epoch 29/100
# 1920/1920 - 11s - loss: 0.0016 - mean_absolute_error: 0.0280 - val_loss: 0.0030 - val_mean_absolute_error: 0.0487
# Epoch 30/100
# 1920/1920 - 11s - loss: 0.0017 - mean_absolute_error: 0.0274 - val_loss: 0.0029 - val_mean_absolute_error: 0.0481
# Epoch 31/100
# 1920/1920 - 11s - loss: 0.0015 - mean_absolute_error: 0.0274 - val_loss: 0.0027 - val_mean_absolute_error: 0.0409
# Epoch 32/100
# 1920/1920 - 11s - loss: 0.0015 - mean_absolute_error: 0.0266 - val_loss: 0.0048 - val_mean_absolute_error: 0.0597
# Epoch 33/100
# 1920/1920 - 10s - loss: 0.0016 - mean_absolute_error: 0.0274 - val_loss: 0.0058 - val_mean_absolute_error: 0.0655
# Epoch 34/100
# 1920/1920 - 11s - loss: 0.0014 - mean_absolute_error: 0.0260 - val_loss: 0.0049 - val_mean_absolute_error: 0.0603
# Epoch 35/100
# 1920/1920 - 11s - loss: 0.0017 - mean_absolute_error: 0.0278 - val_loss: 0.0025 - val_mean_absolute_error: 0.0429
# Epoch 36/100
# 1920/1920 - 11s - loss: 0.0016 - mean_absolute_error: 0.0270 - val_loss: 0.0072 - val_mean_absolute_error: 0.0736
# Epoch 37/100
# 1920/1920 - 11s - loss: 0.0015 - mean_absolute_error: 0.0260 - val_loss: 0.0027 - val_mean_absolute_error: 0.0462
# Epoch 38/100
# 1920/1920 - 11s - loss: 0.0015 - mean_absolute_error: 0.0260 - val_loss: 0.0046 - val_mean_absolute_error: 0.0588
# Epoch 39/100
# 1920/1920 - 11s - loss: 0.0015 - mean_absolute_error: 0.0266 - val_loss: 0.0023 - val_mean_absolute_error: 0.0381
# Epoch 40/100
# 1920/1920 - 11s - loss: 0.0014 - mean_absolute_error: 0.0256 - val_loss: 0.0025 - val_mean_absolute_error: 0.0439
# Epoch 41/100
# 1920/1920 - 11s - loss: 0.0016 - mean_absolute_error: 0.0265 - val_loss: 0.0053 - val_mean_absolute_error: 0.0629
# Epoch 42/100
# 1920/1920 - 11s - loss: 0.0017 - mean_absolute_error: 0.0264 - val_loss: 0.0022 - val_mean_absolute_error: 0.0404
# Epoch 43/100
# 1920/1920 - 11s - loss: 0.0014 - mean_absolute_error: 0.0258 - val_loss: 0.0036 - val_mean_absolute_error: 0.0533
# Epoch 44/100
# 1920/1920 - 11s - loss: 0.0013 - mean_absolute_error: 0.0242 - val_loss: 0.0028 - val_mean_absolute_error: 0.0476
# Epoch 45/100
# 1920/1920 - 11s - loss: 0.0014 - mean_absolute_error: 0.0253 - val_loss: 0.0050 - val_mean_absolute_error: 0.0605
# Epoch 46/100
# 1920/1920 - 11s - loss: 0.0013 - mean_absolute_error: 0.0248 - val_loss: 0.0019 - val_mean_absolute_error: 0.0360
# Epoch 47/100
# 1920/1920 - 11s - loss: 0.0015 - mean_absolute_error: 0.0253 - val_loss: 0.0039 - val_mean_absolute_error: 0.0545
# Epoch 48/100
# 1920/1920 - 11s - loss: 0.0013 - mean_absolute_error: 0.0246 - val_loss: 0.0024 - val_mean_absolute_error: 0.0437
# Epoch 49/100
# 1920/1920 - 11s - loss: 0.0014 - mean_absolute_error: 0.0255 - val_loss: 0.0020 - val_mean_absolute_error: 0.0393
# Epoch 50/100
# 1920/1920 - 11s - loss: 0.0013 - mean_absolute_error: 0.0248 - val_loss: 0.0022 - val_mean_absolute_error: 0.0417
# Epoch 51/100
# 1920/1920 - 11s - loss: 0.0012 - mean_absolute_error: 0.0238 - val_loss: 0.0016 - val_mean_absolute_error: 0.0341
# Epoch 52/100
# 1920/1920 - 11s - loss: 0.0014 - mean_absolute_error: 0.0249 - val_loss: 0.0016 - val_mean_absolute_error: 0.0315
# Epoch 53/100
# 1920/1920 - 11s - loss: 0.0013 - mean_absolute_error: 0.0240 - val_loss: 0.0017 - val_mean_absolute_error: 0.0354
# Epoch 54/100
# 1920/1920 - 11s - loss: 0.0013 - mean_absolute_error: 0.0241 - val_loss: 0.0037 - val_mean_absolute_error: 0.0525
# Epoch 55/100
# 1920/1920 - 11s - loss: 0.0012 - mean_absolute_error: 0.0237 - val_loss: 0.0024 - val_mean_absolute_error: 0.0433
# Epoch 56/100
# 1920/1920 - 11s - loss: 0.0014 - mean_absolute_error: 0.0251 - val_loss: 0.0015 - val_mean_absolute_error: 0.0326
# Epoch 57/100
# 1920/1920 - 11s - loss: 0.0012 - mean_absolute_error: 0.0236 - val_loss: 0.0019 - val_mean_absolute_error: 0.0380
# Epoch 58/100
# 1920/1920 - 11s - loss: 0.0013 - mean_absolute_error: 0.0237 - val_loss: 0.0031 - val_mean_absolute_error: 0.0489
# Epoch 59/100
# 1920/1920 - 11s - loss: 0.0014 - mean_absolute_error: 0.0243 - val_loss: 0.0015 - val_mean_absolute_error: 0.0307
# Epoch 60/100
# 1920/1920 - 12s - loss: 0.0012 - mean_absolute_error: 0.0232 - val_loss: 0.0021 - val_mean_absolute_error: 0.0401
# Epoch 61/100
# 1920/1920 - 11s - loss: 0.0013 - mean_absolute_error: 0.0237 - val_loss: 0.0021 - val_mean_absolute_error: 0.0400
# Epoch 62/100
# 1920/1920 - 11s - loss: 0.0013 - mean_absolute_error: 0.0235 - val_loss: 0.0013 - val_mean_absolute_error: 0.0296
# Epoch 63/100
# 1920/1920 - 11s - loss: 0.0011 - mean_absolute_error: 0.0229 - val_loss: 0.0012 - val_mean_absolute_error: 0.0280
# Epoch 64/100
# 1920/1920 - 10s - loss: 0.0011 - mean_absolute_error: 0.0227 - val_loss: 0.0064 - val_mean_absolute_error: 0.0701
# Epoch 65/100
# 1920/1920 - 11s - loss: 0.0012 - mean_absolute_error: 0.0229 - val_loss: 0.0021 - val_mean_absolute_error: 0.0404
# Epoch 66/100
# 1920/1920 - 11s - loss: 0.0013 - mean_absolute_error: 0.0239 - val_loss: 0.0032 - val_mean_absolute_error: 0.0483
# Epoch 67/100
# 1920/1920 - 11s - loss: 0.0011 - mean_absolute_error: 0.0225 - val_loss: 0.0014 - val_mean_absolute_error: 0.0318
# Epoch 68/100
# 1920/1920 - 11s - loss: 0.0013 - mean_absolute_error: 0.0236 - val_loss: 0.0011 - val_mean_absolute_error: 0.0268
# Epoch 69/100
# 1920/1920 - 11s - loss: 0.0012 - mean_absolute_error: 0.0233 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
# Epoch 70/100
# 1920/1920 - 11s - loss: 0.0012 - mean_absolute_error: 0.0237 - val_loss: 0.0014 - val_mean_absolute_error: 0.0321
# Epoch 71/100
# 1920/1920 - 11s - loss: 0.0012 - mean_absolute_error: 0.0234 - val_loss: 0.0023 - val_mean_absolute_error: 0.0415
# Epoch 72/100
# 1920/1920 - 11s - loss: 0.0013 - mean_absolute_error: 0.0232 - val_loss: 0.0015 - val_mean_absolute_error: 0.0334
# Epoch 73/100
# 1920/1920 - 10s - loss: 0.0011 - mean_absolute_error: 0.0223 - val_loss: 0.0016 - val_mean_absolute_error: 0.0355
# Epoch 74/100
# 1920/1920 - 11s - loss: 0.0011 - mean_absolute_error: 0.0222 - val_loss: 0.0030 - val_mean_absolute_error: 0.0471
# Epoch 75/100
# 1920/1920 - 11s - loss: 0.0012 - mean_absolute_error: 0.0235 - val_loss: 0.0034 - val_mean_absolute_error: 0.0496
# Epoch 76/100
# 1920/1920 - 11s - loss: 0.0012 - mean_absolute_error: 0.0233 - val_loss: 0.0016 - val_mean_absolute_error: 0.0345
# Epoch 77/100
# 1920/1920 - 11s - loss: 0.0011 - mean_absolute_error: 0.0223 - val_loss: 0.0016 - val_mean_absolute_error: 0.0321
# Epoch 78/100
# 1920/1920 - 11s - loss: 0.0012 - mean_absolute_error: 0.0230 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265
# Epoch 79/100
# 1920/1920 - 10s - loss: 0.0012 - mean_absolute_error: 0.0223 - val_loss: 0.0010 - val_mean_absolute_error: 0.0252
# Epoch 80/100
# 1920/1920 - 11s - loss: 0.0010 - mean_absolute_error: 0.0218 - val_loss: 0.0014 - val_mean_absolute_error: 0.0320
# Epoch 81/100
# 1920/1920 - 11s - loss: 0.0011 - mean_absolute_error: 0.0224 - val_loss: 0.0010 - val_mean_absolute_error: 0.0255
# Epoch 82/100
# 1920/1920 - 11s - loss: 0.0011 - mean_absolute_error: 0.0220 - val_loss: 0.0012 - val_mean_absolute_error: 0.0301
# Epoch 83/100
# 1920/1920 - 11s - loss: 0.0011 - mean_absolute_error: 0.0219 - val_loss: 0.0011 - val_mean_absolute_error: 0.0278
# Epoch 84/100
# 1920/1920 - 11s - loss: 0.0011 - mean_absolute_error: 0.0221 - val_loss: 0.0010 - val_mean_absolute_error: 0.0267
# Epoch 85/100
# 1920/1920 - 11s - loss: 0.0012 - mean_absolute_error: 0.0227 - val_loss: 0.0038 - val_mean_absolute_error: 0.0527
# Epoch 86/100
# 1920/1920 - 11s - loss: 0.0011 - mean_absolute_error: 0.0217 - val_loss: 0.0013 - val_mean_absolute_error: 0.0309
# Epoch 87/100
# 1920/1920 - 11s - loss: 0.0010 - mean_absolute_error: 0.0212 - val_loss: 0.0011 - val_mean_absolute_error: 0.0285
# Epoch 88/100
# 1920/1920 - 11s - loss: 0.0011 - mean_absolute_error: 0.0219 - val_loss: 0.0015 - val_mean_absolute_error: 0.0340
# Epoch 89/100
# 1920/1920 - 11s - loss: 9.7806e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0010 - val_mean_absolute_error: 0.0269
# Epoch 90/100
# 1920/1920 - 11s - loss: 0.0012 - mean_absolute_error: 0.0226 - val_loss: 0.0012 - val_mean_absolute_error: 0.0297
# Epoch 91/100
# 1920/1920 - 11s - loss: 0.0010 - mean_absolute_error: 0.0217 - val_loss: 0.0018 - val_mean_absolute_error: 0.0370
# Epoch 92/100
# 1920/1920 - 11s - loss: 0.0011 - mean_absolute_error: 0.0222 - val_loss: 0.0024 - val_mean_absolute_error: 0.0415
# Epoch 93/100
# 1920/1920 - 11s - loss: 0.0011 - mean_absolute_error: 0.0224 - val_loss: 9.7200e-04 - val_mean_absolute_error: 0.0265
# Epoch 94/100
# 1920/1920 - 11s - loss: 9.9382e-04 - mean_absolute_error: 0.0212 - val_loss: 0.0011 - val_mean_absolute_error: 0.0266
# Epoch 95/100
# 1920/1920 - 11s - loss: 0.0011 - mean_absolute_error: 0.0218 - val_loss: 9.3070e-04 - val_mean_absolute_error: 0.0272
# Epoch 96/100
# 1920/1920 - 11s - loss: 0.0011 - mean_absolute_error: 0.0213 - val_loss: 0.0015 - val_mean_absolute_error: 0.0327
# Epoch 97/100
# 1920/1920 - 10s - loss: 0.0011 - mean_absolute_error: 0.0217 - val_loss: 9.9766e-04 - val_mean_absolute_error: 0.0269
# Epoch 98/100
# 1920/1920 - 11s - loss: 0.0010 - mean_absolute_error: 0.0216 - val_loss: 8.5292e-04 - val_mean_absolute_error: 0.0242
# Epoch 99/100
# 1920/1920 - 11s - loss: 9.6620e-04 - mean_absolute_error: 0.0206 - val_loss: 9.0841e-04 - val_mean_absolute_error: 0.0255
# Epoch 100/100
# 1920/1920 - 10s - loss: 0.0010 - mean_absolute_error: 0.0215 - val_loss: 9.3944e-04 - val_mean_absolute_error: 0.0270
